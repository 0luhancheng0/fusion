# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from run_per_textual_analysis import CrossModelAnalyzer
analyzer = CrossModelAnalyzer()
# Out:
# Loading cached results from /home/lcheng/oz318/fusion/logs/results.json
# /fred/oz318/luhanc/fusion/run_per_textual_analysis.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transformer_fusion["output_modality"] = transformer_fusion.kwargs.map(
# /fred/oz318/luhanc/fusion/run_per_textual_analysis.py:142: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transformer_fusion["model_type"] = transformer_fusion.apply(

# %%
analyzer.per_textual_model()
